# %%
# !cd
# Out:
# C:\Users\ajaio\OneDrive\Desktop\Projects\Web-Scraper\src\nbs

# %%
from setup import init_django
init_django("home")

# %%
# !cd
# Out:
# C:\Users\ajaio\OneDrive\Desktop\Projects\Web-Scraper\src

# %%
url = "https://www.amazon.com/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1?crid=S7XB3LZ1RMA9&dib=eyJ2IjoiMSJ9.AHjTd7ZFe8s8RHzX7QExwI18XbKB9ZvJhalPyI4dHJxXF6vNoBytUGouevobExtfePwpkBLq1_6eFwyVs2Tswt88cOg2QGAKvjYJxCUZNPa1ZG5Nn1lUPCH_zU4FOHcWKPIV_rGgrnmkKFZ3yUzOj1M7Ew_dgQWduF4jUxu7RfSt3VYpwR9SB8uj4PWRCGBHe22Pxgq0HybwuPPQp-r-Elv06I6bcUdF0_RMeMzYJYc.j1KQHH7DOdfjLy7ULFrGrdeQbZDs1gt2cPhHdzu_bBE&dib_tag=se&keywords=ps5&qid=1718702460&sprefix=ps5%2Bcon%2Caps%2C397&sr=8-1&th=1"

# %%
import helpers

# %%
helpers.scrape(url)
# Out:
# Connecting to Scraping Browser...
# Connected! Navigating to https://www.amazon.com/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1?crid=S7XB3LZ1RMA9&dib=eyJ2IjoiMSJ9.AHjTd7ZFe8s8RHzX7QExwI18XbKB9ZvJhalPyI4dHJxXF6vNoBytUGouevobExtfePwpkBLq1_6eFwyVs2Tswt88cOg2QGAKvjYJxCUZNPa1ZG5Nn1lUPCH_zU4FOHcWKPIV_rGgrnmkKFZ3yUzOj1M7Ew_dgQWduF4jUxu7RfSt3VYpwR9SB8uj4PWRCGBHe22Pxgq0HybwuPPQp-r-Elv06I6bcUdF0_RMeMzYJYc.j1KQHH7DOdfjLy7ULFrGrdeQbZDs1gt2cPhHdzu_bBE&dib_tag=se&keywords=ps5&qid=1718702460&sprefix=ps5%2Bcon%2Caps%2C397&sr=8-1&th=1
# Waiting captcha to solve...
# Captcha solve status: not_detected
# Navigated! Scraping page content...
# ...
